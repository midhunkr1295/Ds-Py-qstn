# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('https://gist.githubusercontent.com/awinabi/8871f6daf8ae461f80212b8dc065efc5/raw/bb575de734a9ca47a42f30058051a032d0e1feed/timelog.csv')

# %%
data=pd.DataFrame(data=df,columns=('Employee_ID', 'Date', 'Swipe_In_Time', 'Swipe_Out_Time'))
data
# Out:
#     Employee_ID        Date Swipe_In_Time Swipe_Out_Time
# 0        US9001  2020-01-01         11:10          01:19
# 1        US9001  2020-01-01         02:30          04:30
# 2        US9001  2020-01-01         05:00          05:50
# 3        US9001  2020-01-02         09:44          10:57
# 4        US9001  2020-01-02         11:14          01:28
# ..          ...         ...           ...            ...
# 614      US9017  2020-01-30         05:19          06:04
# 615      US9017  2020-01-31         09:36          10:59
# 616      US9017  2020-01-31         11:21          01:28
# 617      US9017  2020-01-31         02:45          04:47
# 618      US9017  2020-01-31         05:08          06:00
#
# [619 rows x 4 columns]

# %%
def daily_time_logged(date):
    dd=data.loc[data['Date'].str.contains("2020-01-01", case=False)]

# %%
# Out:
#   Employee_ID        Date Swipe_In_Time Swipe_Out_Time
# 0      US9001  2020-01-01         11:10          01:19
# 1      US9001  2020-01-01         02:30          04:30
# 2      US9001  2020-01-01         05:00          05:50

# %%
e['Swipe_In_Time'][0]
# Out:
# '11:10'

# %% [markdown]
# # Q3

# %%
qs2=pd.read_csv('https://gist.githubusercontent.com/awinabi/409469839ef44dfdffe997ff2677ed18/raw/8b64085e863db99e5a00d2927e846f9f5d027fe1/store-dataset.csv')

# %%
qs2
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
qs2['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
gp=qs2.groupby(['Category']).sum()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=gp.index,y='Quantity',data=gp)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Quantity'>

# %%
qs2.groupby(['Order Date','Category']).sum()
# Out:
#                             Row ID  Postal Code     Sales  Quantity  Discount  \
# Order Date Category
# 1/1/2017   Furniture         21002       288768   975.490        24       1.1
#            Office Supplies   47051       439832   506.338        32       2.8
# 1/10/2014  Furniture           867        22153    51.940         1       0.0
#            Office Supplies     866        22153     2.890         1       0.0
# 1/10/2015  Furniture          1670        10011  1018.104         4       0.4
# ...                            ...          ...       ...       ...       ...
# 9/9/2016   Furniture          3568        75220    15.008         4       0.6
#            Office Supplies    3987       105231    69.984         6       0.4
# 9/9/2017   Furniture         19922       210778   482.564        14       1.1
#            Office Supplies  105590      1079403  1427.003        70       4.8
#            Technology        11375       147434  2446.494        17       0.8
#
# ...

# %%
sns.lineplot(x='Order Date',y='Profit',data=qs2,style=5)
# Out:
# <AxesSubplot:xlabel='Order Date', ylabel='Profit'>

# %%
#qs2.groupby(qs2['Order Date'].map(lambda x: x.year))
